# %%
import pandas as pd
import numpy as np

# %%
plot(arange(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9eb9c2bc6e8c> in <module>()
# ----> 1 plot(arange(5))
#
# NameError: name 'plot' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(arange(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-233e65560537> in <module>()
# ----> 1 plt.plot(arange(5))
#
# NameError: name 'arange' is not defined

# %%
# %pylab inline
plot(arange(5))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ukraine = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/x_ukrainian.csv", header=None)
yemeni = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/x_yemeni.csv", header=None)
ss = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/x_south_sudan.csv", header=None)
iraqi = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/x_Iraqi.csv", header=None)
canada = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/v_canada.csv",header=None)
denmark = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/v_Denmark.csv", header=None)
france = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/france_safety.csv", header=None)
germany = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/germany_safety.csv", header=None)
uk = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/safety_crisys_disaster.csv", header=None)

# %%
uk[1]
# Out:
# 0     -2.521249
# 1     -0.059595
# 2     -1.006921
# 3     -2.331475
# 4     -4.018913
# 5     -3.402490
# 6     -5.567355
# 7     -2.739726
# 8     -7.754308
# 9     -2.240471
# 10    -1.981707
# 11    -4.476568
# 12     3.360000
# 13    -0.033926
# 14    -2.620452
# 15    -3.039856
# 16    -2.652567
# 17    -4.313145
# 18    -1.507357
# 19     0.772087
# 20    -3.039136
# 21     0.086478
# 22     1.789709
# 23    -5.722892
# 24    -2.046400
# 25    -0.046111
# 26    -3.088169
# 27    -2.569626
# 28    -0.573248
# 29     2.382302
#          ...
# 628   -3.241161
# 629   -2.930097
# 630   -2.995077
# 631   -2.903121
# 632   -2.953432
# 633   -2.965399
# 634   -3.178946
# 635   -3.058631
# 636   -3.494739
# 637   -3.270994
# 638   -3.444417
# 639   -3.418611
# 640   -3.259631
# 641   -3.513282
# 642   -3.953562
# 643   -3.896846
# 644   -3.712664
# 645   -4.087834
# 646   -3.596247
# 647   -3.530516
# 648   -3.500506
# 649   -3.030260
# 650   -3.013717
# 651   -1.931217
# ...

# %%
uk[1].hist(bin=50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-21441412619e> in <module>()
# ----> 1 uk[1].hist(bin=50)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2987         values = self.dropna().values
#    2988
# -> 2989         ax.hist(values, bins=bins, **kwds)
#    2990         ax.grid(grid)
#    2991         axes = np.array([ax])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
# ...

# %%
uk[1].hist(bins=50)

# %%
fig = plt.figure(figsize=(12,3))

# %%
ax1 = fig.add_subplot(121)

# %%
uk[1].boxplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c88b53945d28> in <module>()
# ----> 1 uk[1].boxplot()
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'boxplot'

# %%
uk.boxplot(column=1)

# %%
fig.boxplot(uk[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-47a9cae03b72> in <module>()
# ----> 1 fig.boxplot(uk[1])
#
# AttributeError: 'Figure' object has no attribute 'boxplot'

# %%
plt.boxplot(uk[1])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c392bc50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c393cb10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c3947e10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c39477d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c392bd90>,
#   <matplotlib.lines.Line2D at 0x7f46c393c4d0>]}

# %%
plt.boxplot(france[1])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c3ce14d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c3cf82d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c3e8cc90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c3e8cb10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c3ce1550>,
#   <matplotlib.lines.Line2D at 0x7f46c3ce1f50>]}

# %%
data = [uk[1], france[1], germany[1], denmark[1], iraqi[1], ukraine[10], canada[1], ss[1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-fd25e421f0be> in <module>()
# ----> 1 data = [uk[1], france[1], germany[1], denmark[1], iraqi[1], ukraine[10], canada[1], ss[1]]
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
data = [uk[1], france[1], germany[1], denmark[1], iraqi[1], ukraine[1], canada[1], ss[1]]

# %%
plot.boxplot(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-a07c4769a5d6> in <module>()
# ----> 1 plot.boxplot(data)
#
# AttributeError: 'function' object has no attribute 'boxplot'

# %%
plt.boxplot(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-e36b3d000b95> in <module>()
# ----> 1 plt.boxplot(data)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
plt.boxplot(uk[1], label='UK')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-77a3608bf05a> in <module>()
# ----> 1 plt.boxplot(uk[1], label='UK')
#
# TypeError: boxplot() got an unexpected keyword argument 'label'

# %%
plt.figure()
plt.boxplot(uk[1], 1)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c362e890>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c3642750>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c3651a50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c3651410>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c362e9d0>,
#   <matplotlib.lines.Line2D at 0x7f46c3642110>]}

# %%
plt.figure()
plt.boxplot(france[1], 2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c35c8610>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c35d54d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c355f7d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c355f190>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c35c8750>,
#   <matplotlib.lines.Line2D at 0x7f46c35c8e50>]}

# %%
plt.boxplot(uk[1], france[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-b27602f4adc4> in <module>()
# ----> 1 plt.boxplot(uk[1], france[1])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
plt.boxplot([uk[1], france[1]])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c341d050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c341df50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c3448290>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c342dc10>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c341d210>,
# ...
#   <matplotlib.lines.Line2D at 0x7f46c3477550>]}

# %%
labels = ['UK', 'DE', 'FR', ]
plt.boxplot([uk[1], germany[1], france[1]], labels=labels)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c331cdd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c332ad10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c3342050>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c33369d0>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c331cf90>,
# ...
#   <matplotlib.lines.Line2D at 0x7f46c32e6f10>]}

# %%
labels = ['GBR', 'DEU', 'FRA', 'DNK', 'SSD', 'UKR', 'IRQ', 'YEM']

# %%
plt.setp(labels, rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-0a4f444fa21b> in <module>()
# ----> 1 plt.setp(labels, rotation=90)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in setp(*args, **kwargs)
#     358 @docstring.copy(_setp)
#     359 def setp(*args, **kwargs):
# --> 360     return _setp(*args, **kwargs)
#     361
#     362
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in setp(obj, *args, **kwargs)
#    1501         funcvals[args[i]] = args[i + 1]
#    1502
# -> 1503     ret = [o.update(funcvals) for o in objs]
#    1504     ret.extend([o.set(**kwargs) for o in objs])
#    1505     return [x for x in cbook.flatten(ret)]
#
# AttributeError: 'str' object has no attribute 'update'

# %%
plt.setp(labels, rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-0a4f444fa21b> in <module>()
# ----> 1 plt.setp(labels, rotation=90)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in setp(*args, **kwargs)
#     358 @docstring.copy(_setp)
#     359 def setp(*args, **kwargs):
# --> 360     return _setp(*args, **kwargs)
#     361
#     362
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in setp(obj, *args, **kwargs)
#    1501         funcvals[args[i]] = args[i + 1]
#    1502
# -> 1503     ret = [o.update(funcvals) for o in objs]
#    1504     ret.extend([o.set(**kwargs) for o in objs])
#    1505     return [x for x in cbook.flatten(ret)]
#
# AttributeError: 'str' object has no attribute 'update'

# %%
labels = ['GBR', 'DEU', 'FRA', 'DNK', 'CAN', 'SSD', 'UKR', 'IRQ', 'YEM']
data = [uk[1], germany[1], france[1], denmark[0], canada[0], ss[0], ukraine[0], iraqi[0], yemeni[0]]

# %%
print data
# Out:
# [0     -2.521249
# 1     -0.059595
# 2     -1.006921
# 3     -2.331475
# 4     -4.018913
# 5     -3.402490
# 6     -5.567355
# 7     -2.739726
# 8     -7.754308
# 9     -2.240471
# 10    -1.981707
# 11    -4.476568
# 12     3.360000
# 13    -0.033926
# 14    -2.620452
# 15    -3.039856
# 16    -2.652567
# 17    -4.313145
# 18    -1.507357
# 19     0.772087
# 20    -3.039136
# 21     0.086478
# 22     1.789709
# 23    -5.722892
# 24    -2.046400
# 25    -0.046111
# 26    -3.088169
# 27    -2.569626
# 28    -0.573248
# 29     2.382302
#          ...
# 628   -3.241161
# 629   -2.930097
# 630   -2.995077
# 631   -2.903121
# 632   -2.953432
# 633   -2.965399
# 634   -3.178946
# 635   -3.058631
# 636   -3.494739
# 637   -3.270994
# 638   -3.444417
# 639   -3.418611
# 640   -3.259631
# 641   -3.513282
# 642   -3.953562
# 643   -3.896846
# 644   -3.712664
# 645   -4.087834
# 646   -3.596247
# 647   -3.530516
# 648   -3.500506
# 649   -3.030260
# 650   -3.013717
# 651   -1.931217
# ...

# %%
plt.boxplot(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-e36b3d000b95> in <module>()
# ----> 1 plt.boxplot(data)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
len(data)
# Out:
# 9

# %%
data[0]
# Out:
# 0     -2.521249
# 1     -0.059595
# 2     -1.006921
# 3     -2.331475
# 4     -4.018913
# 5     -3.402490
# 6     -5.567355
# 7     -2.739726
# 8     -7.754308
# 9     -2.240471
# 10    -1.981707
# 11    -4.476568
# 12     3.360000
# 13    -0.033926
# 14    -2.620452
# 15    -3.039856
# 16    -2.652567
# 17    -4.313145
# 18    -1.507357
# 19     0.772087
# 20    -3.039136
# 21     0.086478
# 22     1.789709
# 23    -5.722892
# 24    -2.046400
# 25    -0.046111
# 26    -3.088169
# 27    -2.569626
# 28    -0.573248
# 29     2.382302
#          ...
# 628   -3.241161
# 629   -2.930097
# 630   -2.995077
# 631   -2.903121
# 632   -2.953432
# 633   -2.965399
# 634   -3.178946
# 635   -3.058631
# 636   -3.494739
# 637   -3.270994
# 638   -3.444417
# 639   -3.418611
# 640   -3.259631
# 641   -3.513282
# 642   -3.953562
# 643   -3.896846
# 644   -3.712664
# 645   -4.087834
# 646   -3.596247
# 647   -3.530516
# 648   -3.500506
# 649   -3.030260
# 650   -3.013717
# 651   -1.931217
# ...

# %%
plt.boxplot([uk[1], france[1], germany[1], denmark[1], iraqi[1], ukraine[10], canada[1], ss[1]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-1a4a59ecd18f> in <module>()
# ----> 1 plt.boxplot([uk[1], france[1], germany[1], denmark[1], iraqi[1], ukraine[10], canada[1], ss[1]])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
[uk[1], france[1], germany[1]]
# Out:
# [0     -2.521249
#  1     -0.059595
#  2     -1.006921
#  3     -2.331475
#  4     -4.018913
#  5     -3.402490
#  6     -5.567355
#  7     -2.739726
#  8     -7.754308
#  9     -2.240471
#  10    -1.981707
#  11    -4.476568
#  12     3.360000
#  13    -0.033926
#  14    -2.620452
#  15    -3.039856
#  16    -2.652567
#  17    -4.313145
#  18    -1.507357
#  19     0.772087
#  20    -3.039136
#  21     0.086478
#  22     1.789709
#  23    -5.722892
#  24    -2.046400
#  25    -0.046111
#  26    -3.088169
#  27    -2.569626
#  28    -0.573248
#  29     2.382302
#           ...
#  628   -3.241161
#  629   -2.930097
#  630   -2.995077
#  631   -2.903121
#  632   -2.953432
#  633   -2.965399
#  634   -3.178946
#  635   -3.058631
#  636   -3.494739
#  637   -3.270994
#  638   -3.444417
#  639   -3.418611
#  640   -3.259631
#  641   -3.513282
#  642   -3.953562
#  643   -3.896846
#  644   -3.712664
#  645   -4.087834
#  646   -3.596247
#  647   -3.530516
#  648   -3.500506
# ...

# %%
plt.boxplot([uk[1], france[1], germany[1]])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c3175f50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c3195e90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c316d1d0>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c3196b50>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c3195150>,
# ...
#   <matplotlib.lines.Line2D at 0x7f46c30f50d0>]}

# %%
plt.boxplot([uk[1], france[1], germany[1],  iraqi[1], ukraine[1],canada[1], ss[1]])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c3284b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c33177d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c31ee090>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c31ee190>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c322be90>,
# ...
#   <matplotlib.lines.Line2D at 0x7f46c350a110>]}

# %%
plt.boxplot([uk[1], france[1], germany[1],  iraqi[1], ukraine[1],canada[1], ss[1]])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c34f4ed0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c3751e10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c372e150>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c373bad0>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c37510d0>,
# ...
#   <matplotlib.lines.Line2D at 0x7f46c3024c10>]}

# %%
print labels
# Out:
# ['GBR', 'DEU', 'FRA', 'DNK', 'CAN', 'SSD', 'UKR', 'IRQ', 'YEM']

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[0], canada[1], ss[1], ukraine[1], iraqi[1], yemeni[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-40ff8f10b444> in <module>()
# ----> 1 plt.boxplot([uk[1], germany[1], france[1], denmark[0], canada[1], ss[1], ukraine[1], iraqi[1], yemeni[1]])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[0], canada[1], ss[1], ukraine[1], iraqi[1], yemeni[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-40ff8f10b444> in <module>()
# ----> 1 plt.boxplot([uk[1], germany[1], france[1], denmark[0], canada[1], ss[1], ukraine[1], iraqi[1], yemeni[1]])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[0], canada[1], ss[1], ukraine[1], iraqi[1])
# Out:
#   File "<ipython-input-45-a89627b79f23>", line 1
#     plt.boxplot([uk[1], germany[1], france[1], denmark[0], canada[1], ss[1], ukraine[1], iraqi[1])
#                                                                                                  ^
# SyntaxError: invalid syntax

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[0], canada[1], ss[1], ukraine[1], iraqi[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-e7b29bf3af75> in <module>()
# ----> 1 plt.boxplot([uk[1], germany[1], france[1], denmark[0], canada[1], ss[1], ukraine[1], iraqi[1]])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1], yemeni[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-526d8543774e> in <module>()
# ----> 1 plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1], yemeni[1]])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1])
# Out:
#   File "<ipython-input-48-579226c24250>", line 1
#     plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1])
#                                                                                                  ^
# SyntaxError: invalid syntax

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-b2443c017e19> in <module>()
# ----> 1 plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1]])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1]])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c2acdcd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c2afac10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c2adff10>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c2adf8d0>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c2acde90>,
# ...
#   <matplotlib.lines.Line2D at 0x7f46c2c5ee10>]}

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1]]
# Out:
#   File "<ipython-input-51-407f7a200871>", line 1
#     plt.boxplot([uk[1], germany[1], france[1], denmark[1]]
#                                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-b613d9858648> in <module>()
# ----> 1 plt.boxplot([uk[1], germany[1], france[1], denmark[1]])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
demark[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-3f064b560c99> in <module>()
# ----> 1 demark[1]
#
# NameError: name 'demark' is not defined

# %%
denmark.describe()
# Out:
#                  0                  1
# count          366                366
# unique         366                366
# top     05/06/2011  5.988878847568922
# freq             1                  1

# %%
denmark[1].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-a00752a16f27> in <module>()
# ----> 1 denmark[1].astype(float)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, raise_on_error, **kwargs)
#    3052         # else, only a single dtype is given
#    3053         new_data = self._data.astype(dtype=dtype, copy=copy,
# -> 3054                                      raise_on_error=raise_on_error, **kwargs)
#    3055         return self._constructor(new_data).__finalize__(self)
#    3056
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    3187
#    3188     def astype(self, dtype, **kwargs):
# -> 3189         return self.apply('astype', dtype=dtype, **kwargs)
#    3190
#    3191     def convert(self, **kwargs):
#
# ...

# %%
plt.boxplot([uk[1], germany[1], france[1], canada[1], ss[1], ukraine[1], iraqi[1]])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c2deb050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c2df9e10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c2d7e390>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c2df9110>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c2deb4d0>,
# ...
#   <matplotlib.lines.Line2D at 0x7f46c2fd5050>]}

# %%
labels
# Out:
# ['GBR', 'DEU', 'FRA', 'DNK', 'CAN', 'SSD', 'UKR', 'IRQ', 'YEM']

# %%
labels = ['GBR', 'DEU', 'FRA', 'CAN', 'SSD', 'UKR', 'IRQ', 'YEM']

# %%
plt.boxplot([uk[1], germany[1], france[1], canada[1], ss[1], ukraine[1], iraqi[1]], labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-4962c99688c3> in <module>()
# ----> 1 plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1]], labels)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, hold, data)
#    2784                          whiskerprops=whiskerprops,
#    2785                          manage_xticks=manage_xticks, autorange=autorange,
# -> 2786                          zorder=zorder, data=data)
#    2787     finally:
#    2788         ax._hold = washold
#
# ...

# %%
plt.boxplot([uk[1], germany[1], france[1], canada[1], ss[1], ukraine[1], iraqi[1]], labels)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f46c2a08d10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f46c29e5c50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f46c29f0f50>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f46c29f0910>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f46c2a08ed0>,
# ...
#   <matplotlib.lines.Line2D at 0x7f46c2969a10>]}

# %%
plt.setp(labels, rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-0a4f444fa21b> in <module>()
# ----> 1 plt.setp(labels, rotation=90)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in setp(*args, **kwargs)
#     358 @docstring.copy(_setp)
#     359 def setp(*args, **kwargs):
# --> 360     return _setp(*args, **kwargs)
#     361
#     362
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in setp(obj, *args, **kwargs)
#    1501         funcvals[args[i]] = args[i + 1]
#    1502
# -> 1503     ret = [o.update(funcvals) for o in objs]
#    1504     ret.extend([o.set(**kwargs) for o in objs])
#    1505     return [x for x in cbook.flatten(ret)]
#
# AttributeError: 'str' object has no attribute 'update'

# %%
plt.xticks(labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-d9d783864b8e> in <module>()
# ----> 1 plt.xticks(labels)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in xticks(*args, **kwargs)
#    1697         labels = ax.get_xticklabels()
#    1698     elif len(args)==1:
# -> 1699         locs = ax.set_xticks(args[0])
#    1700         labels = ax.get_xticklabels()
#    1701     elif len(args)==2:
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in set_xticks(self, ticks, minor)
#    2962         ACCEPTS: sequence of floats
#    2963         """
# -> 2964         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    2965         self.stale = True
#    2966         return ret
#
# ...

# %%
plt.xticks(labels, str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-2eb15941216d> in <module>()
# ----> 1 plt.xticks(labels, str)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in xticks(*args, **kwargs)
#    1700         labels = ax.get_xticklabels()
#    1701     elif len(args)==2:
# -> 1702         locs = ax.set_xticks(args[0])
#    1703         labels = ax.set_xticklabels(args[1], **kwargs)
#    1704     else: raise TypeError('Illegal number of arguments to xticks')
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in set_xticks(self, ticks, minor)
#    2962         ACCEPTS: sequence of floats
#    2963         """
# -> 2964         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    2965         self.stale = True
#    2966         return ret
#
# ...

# %%
plt.boxplot([uk[1], germany[1], france[1], canada[1], ss[1], ukraine[1], iraqi[1]])
plt.xticks([1,2,3,4,5,6,7], labels)
# Out:
# ([<matplotlib.axis.XTick at 0x7f46c25368d0>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %%
denmark = pd.read_csv("/home/weipcao/Desktop/DataMining/DataMiningProject/wwcao/Data/v_Denmark.csv", header=None)

# %%
labels
# Out:
# ['GBR', 'DEU', 'FRA', 'CAN', 'SSD', 'UKR', 'IRQ', 'YEM']

# %%
labels = ['GBR', 'DEU', 'FRA', 'DNK','CAN', 'SSD', 'UKR', 'IRQ', 'YEM']

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1]])
plt.xticks([1,2,3,4,5,6,7], labels)
# Out:
# ([<matplotlib.axis.XTick at 0x7f46c2e29190>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1]])
plt.xticks([1,2,3,4,5,6,7], labels)
ylabel('Average Tone')
savefig('sample.pdf')

# %%
labels = ['GBR', 'DEU', 'FRA', 'DNK','CAN', 'SSD_x', 'UKR_x', 'IRQ_x', 'YEM_x']

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1], yemeni[1]])
plt.xticks([1,2,3,4,5,6,7, 8, 9], labels)
ylabel('Average Tone')
savefig('sample.pdf')

# %%
plt.boxplot([uk[1], germany[1], france[1], denmark[1], canada[1], ss[1], ukraine[1], iraqi[1], yemeni[1]])
plt.xticks([1,2,3,4,5,6,7, 8, 9], labels)
ylabel('Average Tone')
savefig('sample.pdf')

# %%
plt.plot(uk)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-94a635086c2f> in <module>()
# ----> 1 plt.plot(uk)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# ...

# %%
uk.time = pd.to_datetime(uk[0], format='%m/%d/%Y')

# %%
data.set_index(0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-cefe35764646> in <module>()
# ----> 1 data.set_index(0,inplace=True)
#
# AttributeError: 'list' object has no attribute 'set_index'

# %%
uk.set_index(0,inplace=True)

# %%
uk.plot()

# %%
uk.time = pd.to_datetime(uk[0], format='%m/%d/%Y')
uk.set_index(0,inplace=True)
france.time = pd.to_datetime(france[0], format='%m/%d/%Y')
france.set_index(1,inplace=True)
germany.time = pd.to_datetime(germany[0], format='%m/%d/%Y')
germany.set_index(2,inplace=True)
denmark.time = pd.to_datetime(denmark[0], format='%m/%d/%Y')
denmark.set_index(3,inplace=True)
canada.time = pd.to_datetime(canada[0], format='%m/%d/%Y')
canada.set_index(4,inplace=True)

iraqi.time = pd.to_datetime(iraqi[0], format='%m/%d/%Y')
iraqi.set_index(5,inplace=True)
ukraine.time = pd.to_datetime(ukraine[0], format='%m/%d/%Y')
ukraine.set_index(6,inplace=True)
yemeni.time = pd.to_datetime(yemeni[0], format='%m/%d/%Y')
yemeni.set_index(7,inplace=True)
ss.time = pd.to_datetime(ss[0], format='%m/%d/%Y')
ss.set_index(8,inplace=True)

# %%
plt.plot(uk.index, uk.amount)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-b69e202b3ffb> in <module>()
# ----> 1 plt.plot(uk.index, uk.amount)
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'amount'

# %%
plt.plot(uk[0], uk[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-02fd8ca21756> in <module>()
# ----> 1 plt.plot(uk[0], uk[1])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
plt.plot(uk.index, uk[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-b7bb61e7705e> in <module>()
# ----> 1 plt.plot(uk.index, uk[1])
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# ...

# %%
uk.time = pd.to_datetime(uk[0], format='%m/%d/%Y')
uk.set_index(0,inplace=True)
france.time = pd.to_datetime(france[0], format='%m/%d/%Y')
france.set_index(1,inplace=True)
germany.time = pd.to_datetime(germany[0], format='%m/%d/%Y')
germany.set_index(2,inplace=True)
denmark.time = pd.to_datetime(denmark[0], format='%m/%d/%Y')
denmark.set_index(3,inplace=True)
canada.time = pd.to_datetime(canada[0], format='%m/%d/%Y')
canada.set_index(4,inplace=True)

iraqi.time = pd.to_datetime(iraqi[0], format='%m/%d/%Y')
iraqi.set_index(5,inplace=True)
ukraine.time = pd.to_datetime(ukraine[0], format='%m/%d/%Y')
ukraine.set_index(6,inplace=True)
yemeni.time = pd.to_datetime(yemeni[0], format='%m/%d/%Y')
yemeni.set_index(7,inplace=True)
ss.time = pd.to_datetime(ss[0], format='%m/%d/%Y')
ss.set_index(8,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-29503b17ef40> in <module>()
# ----> 1 uk.time = pd.to_datetime(uk[0], format='%m/%d/%Y')
#       2 uk.set_index(0,inplace=True)
#       3 france.time = pd.to_datetime(france[0], format='%m/%d/%Y')
#       4 france.set_index(1,inplace=True)
#       5 germany.time = pd.to_datetime(germany[0], format='%m/%d/%Y')
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# ...

# %%
uk.time = pd.to_datetime(uk[0], format='%m/%d/%Y')
uk.set_index(0,inplace=True)
france.time = pd.to_datetime(france[0], format='%m/%d/%Y')
france.set_index(0,inplace=True)
germany.time = pd.to_datetime(germany[0], format='%m/%d/%Y')
germany.set_index(0,inplace=True)
denmark.time = pd.to_datetime(denmark[0], format='%m/%d/%Y')
denmark.set_index(0,inplace=True)
canada.time = pd.to_datetime(canada[0], format='%m/%d/%Y')
canada.set_index(0,inplace=True)

iraqi.time = pd.to_datetime(iraqi[0], format='%m/%d/%Y')
iraqi.set_index(0,inplace=True)
ukraine.time = pd.to_datetime(ukraine[0], format='%m/%d/%Y')
ukraine.set_index(0,inplace=True)
yemeni.time = pd.to_datetime(yemeni[0], format='%m/%d/%Y')
yemeni.set_index(0,inplace=True)
ss.time = pd.to_datetime(ss[0], format='%m/%d/%Y')
ss.set_index(0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-f287eb8ec645> in <module>()
# ----> 1 uk.time = pd.to_datetime(uk[0], format='%m/%d/%Y')
#       2 uk.set_index(0,inplace=True)
#       3 france.time = pd.to_datetime(france[0], format='%m/%d/%Y')
#       4 france.set_index(0,inplace=True)
#       5 germany.time = pd.to_datetime(germany[0], format='%m/%d/%Y')
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/weipcao/Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# ...

# %%
yemeni.plot()

# %%
fig = yemeni.plot();

# %%
plt.figure();yemeni.plot();

# %%
plt.figure();uk.plot();

# %%
plt.figure();yemeni.plot();uk.plot()

# %%
fig, ax = plt.subplots()
ax.plot_date(uk.index, uk[1])

# %%
fig, ax = plt.subplots()
ax.plot_date(uk.index, uk[1], '-')

# %%
fig, ax = plt.subplots()
ax.plot_date(uk.index, uk[1], '-')
ax.plot_date(france.index, france[1], '-')

# %%
fig, ax = plt.subplots()
ax.plot_date(uk.index, uk[1], '-')
ax.plot_date(france.index, france[1], '-')
ax.plot_date(germany.index, germany[1], '-')

# %%
fig, ax = plt.subplots()
ax.plot_date(uk.index, uk[1], '-')
ax.plot_date(france.index, france[1], '-')
ax.plot_date(germany.index, germany[1], '-')
ax.plot_date(denmark.index, denmark[1], '-')
